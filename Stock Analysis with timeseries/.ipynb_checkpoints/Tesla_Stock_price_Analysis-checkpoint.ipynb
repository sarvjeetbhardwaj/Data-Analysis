# %%
### Install pandas data reader
# !pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\sjitb\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\sjitb\anaconda3\lib\site-packages (from pandas-datareader) (2.27.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\sjitb\anaconda3\lib\site-packages (from pandas-datareader) (1.4.2)
# Requirement already satisfied: lxml in c:\users\sjitb\anaconda3\lib\site-packages (from pandas-datareader) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sjitb\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sjitb\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\sjitb\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.23.3)
# Requirement already satisfied: six>=1.5 in c:\users\sjitb\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas-datareader) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sjitb\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sjitb\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sjitb\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sjitb\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.9)

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
df_tesla = pdr.get_data_yahoo('TSLA') #### Getting Tesla share price data

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2017-10-02  22.913334  22.367332  22.834667  22.768667   79302000.0  22.768667
# 2017-10-03  23.236668  22.085333  22.393333  23.209333  152304000.0  23.209333
# 2017-10-04  23.908001  23.306667  23.416668  23.667334  122452500.0  23.667334
# 2017-10-05  23.829332  23.423332  23.733334  23.688667   62575500.0  23.688667
# 2017-10-06  24.006666  23.483334  23.540001  23.792000   64462500.0  23.792000

# %%
df_tesla.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
#### Plotting the trend of diffrent columns in the dataframe over time
for col in df_tesla.columns:
    df_tesla[col].plot(figsize=(12,4))
    plt.ylabel('Price in $')
    plt.xlabel('Year')
    plt.title(col)
    plt.show()

# %%
### Visualiing plots in a certain time frame - Setlecting the time frame from Jan 2020 to present date 
for col in df_tesla.columns:
    df_tesla[col].plot(xlim=['2020-01','2022-12'],
                       figsize=(12,4),
                       ls='--')
    plt.ylabel('Price in $')
    plt.xlabel('Year')
    plt.title(col)
    plt.show()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2017-10-02 to 2022-09-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1259 non-null   float64
#  1   Low        1259 non-null   float64
#  2   Open       1259 non-null   float64
#  3   Close      1259 non-null   float64
#  4   Volume     1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
# dtypes: float64(6)
# memory usage: 68.9 KB

# %%
df_tesla=df_tesla.reset_index()
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   High       1259 non-null   float64
#  2   Low        1259 non-null   float64
#  3   Open       1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Volume     1259 non-null   float64
#  6   Adj Close  1259 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 69.0 KB

# %%
df_tesla
# Out:
#            Date        High         Low        Open       Close       Volume  \
# 0    2017-10-02   22.913334   22.367332   22.834667   22.768667   79302000.0
# 1    2017-10-03   23.236668   22.085333   22.393333   23.209333  152304000.0
# 2    2017-10-04   23.908001   23.306667   23.416668   23.667334  122452500.0
# 3    2017-10-05   23.829332   23.423332   23.733334   23.688667   62575500.0
# 4    2017-10-06   24.006666   23.483334   23.540001   23.792000   64462500.0
# ...         ...         ...         ...         ...         ...          ...
# 1254 2022-09-26  284.089996  270.309998  271.829987  276.010010   58076900.0
# 1255 2022-09-27  288.670013  277.510010  283.839996  282.940002   61925200.0
# 1256 2022-09-28  289.000000  277.570007  283.079987  287.809998   54664800.0
# 1257 2022-09-29  283.649994  265.779999  282.760010  268.209991   77620600.0
# 1258 2022-09-30  275.570007  262.470001  266.149994  265.250000   67517800.0
#
#        Adj Close
# 0      22.768667
# 1      23.209333
# 2      23.667334
# 3      23.688667
# 4      23.792000
# ...          ...
# 1254  276.010010
# 1255  282.940002
# 1256  287.809998
# 1257  268.209991
# 1258  265.250000
#
# [1259 rows x 7 columns]

# %% [markdown]
# ### Time Resampling

# %%
df_tesla = df_tesla.set_index('Date')
df_tesla
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-10-02   22.913334   22.367332   22.834667   22.768667   79302000.0
# 2017-10-03   23.236668   22.085333   22.393333   23.209333  152304000.0
# 2017-10-04   23.908001   23.306667   23.416668   23.667334  122452500.0
# 2017-10-05   23.829332   23.423332   23.733334   23.688667   62575500.0
# 2017-10-06   24.006666   23.483334   23.540001   23.792000   64462500.0
# ...                ...         ...         ...         ...          ...
# 2022-09-26  284.089996  270.309998  271.829987  276.010010   58076900.0
# 2022-09-27  288.670013  277.510010  283.839996  282.940002   61925200.0
# 2022-09-28  289.000000  277.570007  283.079987  287.809998   54664800.0
# 2022-09-29  283.649994  265.779999  282.760010  268.209991   77620600.0
# 2022-09-30  275.570007  262.470001  266.149994  265.250000   67517800.0
#
#              Adj Close
# Date
# 2017-10-02   22.768667
# 2017-10-03   23.209333
# 2017-10-04   23.667334
# 2017-10-05   23.688667
# 2017-10-06   23.792000
# ...                ...
# 2022-09-26  276.010010
# 2022-09-27  282.940002
# 2022-09-28  287.809998
# 2022-09-29  268.209991
# 2022-09-30  265.250000
#
# [1259 rows x 6 columns]

# %%
df_tesla.resample(rule='A').min() ### Getting the lowest value in each column for every year
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-12-31   20.297333   19.508667   19.966667   19.950666  48661500.0
# 2018-12-31   17.355333   16.306000   16.851999   16.704000  46210500.0
# 2019-12-31   12.445333   11.799333   12.073333   11.931333  36984000.0
# 2020-12-31   26.990667   23.367332   24.980000   24.081333  52073100.0
# 2021-12-31  188.736664  179.830002  184.183334  187.666672  29401800.0
# 2022-12-31  217.973328  206.856674  207.949997  209.386673  41864700.0
#
#              Adj Close
# Date
# 2017-12-31   19.950666
# 2018-12-31   16.704000
# 2019-12-31   11.931333
# 2020-12-31   24.081333
# 2021-12-31  187.666672
# 2022-12-31  209.386673

# %%
df_tesla.resample(rule='A').max() ### Getting the maximum values in each column for every year
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-12-31   24.200001   23.608667   23.798668   23.976667  296871000.0
# 2018-12-31   25.830667   24.474667   25.000000   25.304667  504745500.0
# 2019-12-31   29.020666   28.423332   29.000000   28.729334  450091500.0
# 2020-12-31  239.573334  230.373337  233.330002  235.223328  914082000.0
# 2021-12-31  414.496674  405.666656  411.470001  409.970001  268189500.0
# 2022-12-31  402.666656  378.679993  396.516663  399.926666  151565700.0
#
#              Adj Close
# Date
# 2017-12-31   23.976667
# 2018-12-31   25.304667
# 2019-12-31   28.729334
# 2020-12-31  235.223328
# 2021-12-31  409.970001
# 2022-12-31  399.926666

# %%
for col in df_tesla.resample(rule='A').max().columns: 
    df_tesla[col].resample(rule='A').max().plot()
    plt.ylabel(f'Maximum {col} values in $ ')
    plt.show()

# %%
df_tesla.resample(rule='QS').min() ### Getting the lowest value in each column for each quater in an year
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-10-01   20.297333   19.508667   19.966667   19.950666   48661500.0
# 2018-01-01   17.912001   16.547333   17.099333   17.185333   48294000.0
# 2018-04-01   17.355333   16.306000   16.851999   16.832001   58126500.0
# 2018-07-01   17.889999   16.816668   17.340000   17.549334   54039000.0
# 2018-10-01   17.457333   16.518000   17.016666   16.704000   46210500.0
# 2019-01-01   17.545334   16.964001   17.313999   17.361334   55150500.0
# 2019-04-01   12.445333   11.799333   12.073333   11.931333   76897500.0
# 2019-07-01   14.334667   14.066667   14.240000   14.093333   48382500.0
# 2019-10-01   15.632000   14.952000   15.320000   15.428667   36984000.0
# 2020-01-01   26.990667   23.367332   24.980000   24.081333  142981500.0
# 2020-04-01   32.950668   29.760000   32.068668   30.298000   95436000.0
# 2020-07-01   75.688667   72.033333   72.199997   74.641998   74217000.0
# 2020-10-01  135.660004  126.370003  131.333328  129.346664   52073100.0
# 2021-01-01  205.493332  179.830002  200.183334  187.666672   45473100.0
# 2021-04-01  188.736664  182.326660  184.183334  187.820007   48615900.0
# 2021-07-01  215.733337  206.820007  209.456665  214.460007   29401800.0
# 2021-10-01  260.260010  254.529999  258.733337  258.406677   35042700.0
# 2022-01-01  266.899994  233.333328  233.463333  254.679993   48992700.0
# 2022-04-01  217.973328  206.856674  207.949997  209.386673   49847700.0
# 2022-07-01  230.229996  216.166672  223.000000  227.263336   41864700.0
#
#              Adj Close
# Date
# 2017-10-01   19.950666
# 2018-01-01   17.185333
# 2018-04-01   16.832001
# 2018-07-01   17.549334
# 2018-10-01   16.704000
# 2019-01-01   17.361334
# 2019-04-01   11.931333
# 2019-07-01   14.093333
# 2019-10-01   15.428667
# 2020-01-01   24.081333
# 2020-04-01   30.298000
# 2020-07-01   74.641998
# 2020-10-01  129.346664
# 2021-01-01  187.666672
# 2021-04-01  187.820007
# 2021-07-01  214.460007
# 2021-10-01  258.406677
# 2022-01-01  254.679993
# 2022-04-01  209.386673
# 2022-07-01  227.263336

# %%
df_tesla.resample(rule='BA').min() ### Getting the lowest value in each column for each at the end of each Business day in an year
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-12-29   20.297333   19.508667   19.966667   19.950666  48661500.0
# 2018-12-31   17.355333   16.306000   16.851999   16.704000  46210500.0
# 2019-12-31   12.445333   11.799333   12.073333   11.931333  36984000.0
# 2020-12-31   26.990667   23.367332   24.980000   24.081333  52073100.0
# 2021-12-31  188.736664  179.830002  184.183334  187.666672  29401800.0
# 2022-12-30  217.973328  206.856674  207.949997  209.386673  41864700.0
#
#              Adj Close
# Date
# 2017-12-29   19.950666
# 2018-12-31   16.704000
# 2019-12-31   11.931333
# 2020-12-31   24.081333
# 2021-12-31  187.666672
# 2022-12-30  209.386673

# %%
for col in df_tesla.resample(rule='A').min().columns:
    df_tesla[col].resample(rule = 'A').min().plot(kind='bar')
    plt.show()

# %%
df_tesla['Close'].resample(rule ='M').min().plot(kind='bar',figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>
